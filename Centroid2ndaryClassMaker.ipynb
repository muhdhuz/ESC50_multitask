# %%
import os 
import re

import numpy as np
import math
import tiffspect

import librosa
import librosa.display

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# First some utilities, and the function we want to use to classify our spectrograms 

def weightedCentroid(spect) :
    """
    param: spect - a magnitude spectrum
    Returns the spectral centroid averaged over frames, and weighted by the rms of each frame
    """
    cent = librosa.feature.spectral_centroid(S=spect)
    rms = librosa.feature.rmse(S=spect)
    avg = np.sum(np.multiply(cent, rms))/np.sum(rms)
    return avg

def log2mag(S) : 
    """ Get your log magnitude spectrum back to magnitude"""
    return np.power(10, np.divide(S,20.))

def spectFile2Centroid(fname) :
    """ Our spect files are in log magnitude, and in tiff format"""
    D1, _ = tiffspect.Tiff2LogSpect(fname)
    D2 = log2mag(D1)
    return weightedCentroid(D2)

# %%
# just testing code, demonstrating how to visualize som of the data
wc = spectFile2Centroid('esc50spect//205 - Chirping birds/5-242491-A.tif')
print ('wc is ' + str(wc))

D1, _ = tiffspect.Tiff2LogSpect('esc50spect//205 - Chirping birds/5-242491-A.tif')
D2 = log2mag(D1)
wcs = weightedCentroid(D2)
cent = librosa.feature.spectral_centroid(S=D2)
plt.plot(cent[0])

rms = librosa.feature.rmse(S=D2)
np.set_printoptions(precision=6)
np.set_printoptions(suppress=True)
print(np.column_stack((np.transpose(np.round(cent,2)),np.transpose(np.round(rms,2)))))
# Out:
# wc is 3297.4953264
# [[ 2532.34     0.01]
#  [ 2519.88     0.01]
#  [ 2095.51     0.01]
#  ...,
#  [ 2122.88     0.01]
#  [ 2074.24     0.01]
#  [ 2227.2      0.01]]

# %%
# Next, some utilities for managing files
#----------------------------------------

def fullpathfilenames(directory): 
    '''Returns the full path to all files living in directory (the leaves in the directory tree)
    '''
    fnames = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(directory)) for f in fn]
    return fnames

def esc50files(directory, regexString) :
    filenames = fullpathfilenames(directory)
    return [fname for fname in filenames if re.match(regexString, fname)]

def addClass2Filename(fname, cname, action="move") : 
    newname = re.sub('.tif', '_'+ str(cname) + '.tif', fname)
    if (action == "move") :
        os.rename(fname, newname)
    else :
        print(newname)
    
def filestats (filenames, func) :
    stats = [[fname, func(fname)] for fname in filenames]
    return stats

# %%
def createBalancedClassesWithFunc(topDirectory, regexString, func, numPerClass, action="move") :
    """
    Groups files in topDirectory matching regexString by the single number returned by func.
    Each group will have numPerClass files in it (the total number of files must be divisible by numPerClass)
    Renames them using their group index, gidx: origFilename.tif -> origFilename._gidx_.tif
    if action="move, files are renames. Otherwise, the new names are just printed to console.
    """
    wholelist=esc50files(topDirectory, regexString)
    print(wholelist)
    stats = filestats(wholelist, func)
    stats_ordered = sorted(stats, key=lambda a_entry: a_entry[1])
    classes=np.array(stats_ordered)[:,0].reshape(-1, numPerClass)
    for i in range(len(classes)) :
        for j in range(len(classes[i])) :
            addClass2Filename(classes[i,j],i, action)

    return stats, stats_ordered #returns stuff just for viewing 

#--------------------------------------------------------------------------------
#if you got yourself in trouble, and need to remove all the secondary classnames:
def removeAllSecondaryClassNames(directory) :
    """Remove ALL the 2ndary class names (of the form ._cname_) from ALL files in the directory restoring them to their original"""
    for fname in fullpathfilenames(directory) :
        m = re.match('.*?(\._.*?_)\.tif$', fname)  #grabs the string of all secondary classes if there is a seq of them
        if (m) :
            newname = re.sub(m.group(1), '', fname)
            print('Will move ' + fname + '\n to ' + newname)
            os.rename(fname, newname)
        else :
            print('do nothing with ' + fname)

# %% [markdown]
# # Do it
# This is the call to do your work. Pass in any function that takes spectral files (log mag in tif format) and processes them to return a single number

# %%
#removeAllSecondaryClassNames('esc50spect')
#stats, stats_ordered  = createBalancedClassesWithFunc('esc50spect', '.*/([1-5]).*', spectFile2Centroid, 250, action="print")
#stats, stats_ordered  = createBalancedClassesWithFunc('/Volumes/Bothways/ZCODE/TENSORFLOW/dcn_soundclass/data50', '.*/(train|validate)/([1-5]).*', spectFile2Centroid, 250, action="print")

#change "print" to "move" to actually change the filenames:
stats, stats_ordered  = createBalancedClassesWithFunc('C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt', '.*', spectFile2Centroid, 250, action="move")
# Out:
# ['C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-100032-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-110389-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-30226-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-30344-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-32318-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-59513-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-85362-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\1-97392-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-114280-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-114587-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-116400-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-117271-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-118072-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-118964-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-122104-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\2-122104-b.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-136288-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-144028-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-155312-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-157695-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-163459-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-170015-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-180256-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\3-180977-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-182395-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-183992-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-184575-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-191687-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-192236-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-194754-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-199261-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\4-207124-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-203128-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-203128-b.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-208030-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-212454-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-213855-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-217158-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-231762-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\101 - Dog\\5-9032-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\102 - Rooster\\1-26806-a.tif', 'C:/Users/Huz/Documents/python_scripts/ESC50_multitask/ESC-50-cqt\\102 - Rooster\\1-27724-a.tif', 'C:/Users/H ...
# Tiff2LogSpect: image min is -0.0306613, and image max is 0.869603
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00772657, and image max is 0.92087
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00267621, and image max is 0.799677
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.021895, and image max is 0.927747
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0338073, and image max is 0.862231
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00878027, and image max is 0.920179
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00846991, and image max is 0.918085
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0216042, and image max is 0.844244
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0487733, and image max is 0.894409
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0498188, and image max is 0.865331
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0402543, and image max is 0.912235
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0364823, and image max is 0.929702
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0224456, and image max is 0.917888
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0209999, and image max is 0.894429
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0274859, and image max is 0.890359
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0237052, and image max is 0.830584
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.056038, and image max is 0.812873
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0394778, and image max is 0.89225
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0340821, and image max is 0.860101
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0739412, and image max is 0.896912
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0143872, and image max is 0.88865
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0402415, and image max is 0.845861
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0438885, and image max is 0.849916
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00756304, and image max is 0.866524
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0371733, and image max is 0.885642
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0225856, and image max is 0.892834
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0407806, and image max is 0.888431
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0349608, and image max is 0.811566
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0375782, and image max is 0.812273
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0160244, and image max is 0.868184
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0400142, and image max is 0.774068
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0478296, and image max is 0.878352
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0498601, and image max is 0.839834
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0489701, and image max is 0.8554
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0398404, and image max is 0.855653
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0476422, and image max is 0.867809
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0149385, and image max is 0.773716
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00250012, and image max is 0.863149
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0118993, and image max is 0.847249
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0301619, and image max is 0.805791
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0561195, and image max is 0.805801
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0458009, and image max is 0.890331
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0329655, and image max is 0.838783
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0583386, and image max is 0.893479
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.018048, and image max is 0.795697
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0251218, and image max is 0.833443
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0207405, and image max is 0.804486
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0221373, and image max is 0.785553
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0190565, and image max is 0.800364
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0216626, and image max is 0.787741
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0449774, and image max is 0.791718
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0215073, and image max is 0.840163
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0334896, and image max is 0.830559
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0320637, and image max is 0.808125
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0144074, and image max is 0.852691
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0147121, and image max is 0.912417
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0158697, and image max is 0.928782
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0434926, and image max is 0.806727
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0233722, and image max is 0.8008
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0230127, and image max is 0.779943
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0180803, and image max is 0.738273
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0436468, and image max is 0.726169
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0119227, and image max is 0.727081
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0288911, and image max is 0.862934
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0142653, and image max is 0.85875
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0200711, and image max is 0.80046
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0348059, and image max is 0.903931
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.039296, and image max is 0.801825
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.035906, and image max is 0.843142
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00690973, and image max is 0.8079
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0200629, and image max is 0.743535
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0145596, and image max is 0.882224
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0193273, and image max is 0.868098
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00626491, and image max is 0.871315
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0373431, and image max is 0.85649
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0301681, and image max is 0.761565
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0127339, and image max is 0.798655
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0353603, and image max is 0.787139
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0233516, and image max is 0.792196
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0139137, and image max is 0.880222
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0690561, and image max is 0.862831
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0680788, and image max is 0.854198
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.121871, and image max is 0.81026
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.132691, and image max is 0.902383
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.124648, and image max is 0.906064
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0296756, and image max is 0.844172
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00789622, and image max is 0.875165
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0741027, and image max is 0.837306
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00536727, and image max is 0.896811
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00653862, and image max is 0.912226
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0129002, and image max is 0.90652
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0195023, and image max is 0.934275
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0747558, and image max is 0.902113
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.115017, and image max is 0.93052
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0332767, and image max is 0.948441
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.327977, and image max is 0.930212
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0265161, and image max is 0.910038
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0733402, and image max is 0.964029
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0087862, and image max is 0.884222
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00842414, and image max is 0.932627
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00498218, and image max is 0.90713
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0163714, and image max is 0.819803
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00599663, and image max is 0.918105
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00834188, and image max is 0.952225
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.245567, and image max is 0.909175
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.131459, and image max is 0.893281
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.129565, and image max is 0.948072
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.143763, and image max is 0.936428
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0217358, and image max is 0.836203
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.219332, and image max is 0.924225
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.261301, and image max is 0.855233
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0655691, and image max is 0.898372
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00548067, and image max is 0.818589
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0316621, and image max is 0.810749
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0252908, and image max is 0.886412
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0208366, and image max is 0.82248
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0118385, and image max is 0.817713
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0234346, and image max is 0.89657
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0273359, and image max is 0.81418
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.129836, and image max is 0.867414
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0163816, and image max is 0.811715
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00833205, and image max is 0.842127
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0150773, and image max is 0.86255
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0162868, and image max is 0.828656
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0495623, and image max is 0.853777
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0171937, and image max is 0.82763
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0267818, and image max is 0.898383
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.003823, and image max is 0.832133
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0315051, and image max is 0.863167
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0351928, and image max is 0.863205
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0288973, and image max is 0.820203
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0362124, and image max is 0.831037
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.02411, and image max is 0.740956
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00543306, and image max is 0.78794
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00372093, and image max is 0.890669
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00112115, and image max is 0.848446
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0173638, and image max is 0.795718
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00586297, and image max is 0.870222
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0346638, and image max is 0.808242
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.021663, and image max is 0.920385
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.000344094, and image max is 0.844438
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.000990613, and image max is 0.772808
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00176126, and image max is 0.835517
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0143821, and image max is 0.916693
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0466558, and image max is 0.86021
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0376016, and image max is 0.829763
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0102419, and image max is 0.817361
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00588627, and image max is 0.893971
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.001766, and image max is 0.816795
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00163781, and image max is 0.876163
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.000646117, and image max is 0.879827
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00553753, and image max is 0.785854
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0104018, and image max is 0.874379
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0101456, and image max is 0.856804
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0174298, and image max is 0.898309
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0121876, and image max is 0.782812
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00578, and image max is 0.86886
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0120586, and image max is 0.826666
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0098868, and image max is 0.784509
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0147393, and image max is 0.795272
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0768037, and image max is 0.934789
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0749847, and image max is 0.897351
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00162287, and image max is 0.842827
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0072246, and image max is 0.794673
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00469717, and image max is 0.857874
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00909661, and image max is 0.872487
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.136207, and image max is 0.809116
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.176601, and image max is 0.816882
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0206514, and image max is 0.876224
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.050177, and image max is 0.939649
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0137574, and image max is 0.922814
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0366723, and image max is 0.89377
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0104085, and image max is 0.881056
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0358976, and image max is 0.86127
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0267091, and image max is 0.869468
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.186843, and image max is 0.932856
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.279806, and image max is 0.802392
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.163101, and image max is 0.828903
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.124212, and image max is 0.832884
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.151462, and image max is 0.862127
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0321032, and image max is 0.849826
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0152329, and image max is 0.883013
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.023082, and image max is 0.827369
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0021265, and image max is 0.90133
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.129452, and image max is 0.765465
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0559059, and image max is 0.828949
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00539433, and image max is 0.78053
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.000277343, and image max is 0.768342
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0118454, and image max is 0.861818
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00400003, and image max is 0.841993
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00520831, and image max is 0.837734
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00212684, and image max is 0.885738
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00517788, and image max is 0.887288
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00027652, and image max is 0.905351
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00305533, and image max is 0.82972
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00178206, and image max is 0.876976
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.140861, and image max is 0.924628
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.119896, and image max is 0.973837
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0843949, and image max is 0.89335
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0268928, and image max is 0.876931
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.106089, and image max is 0.696845
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.166851, and image max is 0.816803
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.223376, and image max is 0.822518
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.183642, and image max is 0.757226
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.258416, and image max is 0.723086
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0372847, and image max is 0.746826
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0457108, and image max is 0.935397
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00680021, and image max is 0.919013
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0120424, and image max is 0.761462
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0276708, and image max is 0.683695
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.022427, and image max is 0.639635
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0615327, and image max is 0.693195
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0395584, and image max is 0.706925
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0801472, and image max is 0.760962
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00743586, and image max is 0.848058
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00555145, and image max is 0.719949
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00965888, and image max is 0.8451
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00351207, and image max is 0.801724
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.000983673, and image max is 0.971742
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0211927, and image max is 0.723034
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0417423, and image max is 0.776299
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0190751, and image max is 0.75
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0186962, and image max is 0.750833
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0155087, and image max is 0.743953
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0178601, and image max is 0.769957
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00312393, and image max is 0.863997
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0118231, and image max is 0.791848
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0098989, and image max is 0.824281
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00245567, and image max is 0.92243
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.133462, and image max is 0.900826
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0345558, and image max is 0.73241
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0371942, and image max is 0.713127
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.139148, and image max is 0.912508
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0209961, and image max is 0.829256
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0352357, and image max is 0.753987
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0330829, and image max is 0.709665
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00485388, and image max is 0.740814
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0160811, and image max is 0.70733
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0128867, and image max is 0.640533
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0158028, and image max is 0.758578
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.016444, and image max is 0.852893
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.054941, and image max is 0.809409
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0557797, and image max is 0.823749
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00159239, and image max is 0.747142
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00946186, and image max is 0.779342
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.218888, and image max is 0.879347
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00135243, and image max is 0.834426
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00744276, and image max is 0.808655
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0495156, and image max is 0.775143
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0208435, and image max is 0.828824
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00903465, and image max is 0.816414
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0195381, and image max is 0.8468
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0128226, and image max is 0.710806
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00933058, and image max is 0.863125
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0179689, and image max is 0.799594
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.103123, and image max is 0.752976
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0247918, and image max is 0.771458
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0381639, and image max is 0.788943
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0294036, and image max is 0.80143
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.198862, and image max is 0.770694
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0131434, and image max is 0.820543
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0176931, and image max is 0.855829
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0269113, and image max is 0.868177
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0171768, and image max is 0.821528
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0338797, and image max is 0.826802
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0324723, and image max is 0.893635
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0607408, and image max is 0.816055
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.012553, and image max is 0.791075
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0305357, and image max is 0.803769
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.16381, and image max is 0.780248
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00203361, and image max is 0.784015
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.062798, and image max is 0.875022
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.186705, and image max is 0.810505
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.246676, and image max is 0.862994
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.23416, and image max is 0.895844
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00709496, and image max is 0.853938
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0148447, and image max is 0.817614
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0562985, and image max is 0.885414
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00111069, and image max is 0.724688
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00148665, and image max is 0.854923
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00145475, and image max is 0.869388
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0214489, and image max is 0.974174
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.231997, and image max is 0.888753
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.19179, and image max is 0.875485
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.297956, and image max is 0.887426
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0438248, and image max is 0.949163
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00599297, and image max is 0.926921
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.114874, and image max is 0.827212
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.145601, and image max is 0.921962
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.070318, and image max is 0.854133
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0130212, and image max is 0.821406
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0250396, and image max is 0.858761
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00323488, and image max is 0.841478
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0598127, and image max is 0.950752
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.025507, and image max is 0.884865
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0808691, and image max is 0.892602
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.126909, and image max is 0.969283
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.253659, and image max is 0.89986
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.140603, and image max is 0.876407
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.196366, and image max is 0.879855
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.192436, and image max is 0.908527
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.221849, and image max is 0.885907
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.22552, and image max is 0.885248
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.251474, and image max is 0.889456
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0120094, and image max is 0.866265
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0330502, and image max is 0.876099
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.121521, and image max is 0.918294
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0940166, and image max is 0.844612
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.269609, and image max is 0.931284
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.298364, and image max is 0.914152
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0652009, and image max is 0.880208
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0229675, and image max is 0.96791
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0879652, and image max is 0.859937
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0769735, and image max is 0.877684
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.065029, and image max is 0.926941
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.167746, and image max is 0.878752
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.342829, and image max is 0.879216
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.318751, and image max is 0.913382
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.367545, and image max is 0.882031
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0782154, and image max is 0.867948
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0400798, and image max is 0.849473
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0681633, and image max is 0.85947
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.135529, and image max is 0.876842
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.184377, and image max is 0.864181
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.213941, and image max is 0.87481
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00592921, and image max is 0.838626
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0714776, and image max is 0.836801
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0745517, and image max is 0.889053
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.044747, and image max is 0.845393
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0663635, and image max is 0.819251
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0163515, and image max is 0.781869
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00169051, and image max is 0.821969
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00452956, and image max is 0.812738
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.249084, and image max is 0.842474
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.136281, and image max is 0.840486
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.264962, and image max is 0.855454
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.216163, and image max is 0.916374
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.211, and image max is 0.942423
# ...
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00192167, and image max is 0.811027
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0313622, and image max is 0.868288
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0823948, and image max is 0.879295
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.231002, and image max is 0.896659
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00362574, and image max is 0.800238
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00522202, and image max is 0.861491
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00589052, and image max is 0.859543
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00908319, and image max is 0.910283
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00286588, and image max is 0.836726
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00139316, and image max is 0.816801
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.02942, and image max is 0.865628
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.087506, and image max is 0.890996
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.000207612, and image max is 0.855283
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00811351, and image max is 0.944214
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0583829, and image max is 0.890875
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.15616, and image max is 0.851867
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.187953, and image max is 0.922176
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00842177, and image max is 0.857538
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00506106, and image max is 0.806828
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.013856, and image max is 0.848021
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00402587, and image max is 0.820352
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.172922, and image max is 0.890545
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0350255, and image max is 0.91256
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00349389, and image max is 0.882284
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00147461, and image max is 0.847818
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00299807, and image max is 0.831741
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.105435, and image max is 0.882831
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0365115, and image max is 0.898233
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00576751, and image max is 0.895736
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00408012, and image max is 0.837335
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.118027, and image max is 0.903074
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0782826, and image max is 0.911683
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.105207, and image max is 0.89282
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00449161, and image max is 0.809346
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00820151, and image max is 0.909084
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.010723, and image max is 0.896315
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00866193, and image max is 0.906074
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0013827, and image max is 0.95972
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0794695, and image max is 0.90939
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.121845, and image max is 0.925644
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.100457, and image max is 0.952271
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.105836, and image max is 0.885624
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00841216, and image max is 0.897839
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0108945, and image max is 0.968451
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0350193, and image max is 0.985221
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00447349, and image max is 0.943352
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.047378, and image max is 0.924929
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.027091, and image max is 0.93013
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0173444, and image max is 0.896925
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00806056, and image max is 0.923385
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0101231, and image max is 0.910814
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0267288, and image max is 0.913016
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0168431, and image max is 0.942347
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0336593, and image max is 0.92511
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0317338, and image max is 0.951745
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0168773, and image max is 0.936174
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.199063, and image max is 0.923144
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0273669, and image max is 0.987063
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0161272, and image max is 0.981976
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00675482, and image max is 0.99102
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0369161, and image max is 0.989794
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00935705, and image max is 0.968062
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0201855, and image max is 0.994275
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0179422, and image max is 0.907452
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0346532, and image max is 0.898013
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0121731, and image max is 0.964369
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00236867, and image max is 1.01653
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00357284, and image max is 1.0008
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0140507, and image max is 0.952488
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0232896, and image max is 0.946194
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.026756, and image max is 0.914927
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0251873, and image max is 0.907293
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0249722, and image max is 0.981108
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0330479, and image max is 1.0283
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0584504, and image max is 0.845404
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.270136, and image max is 0.887277
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.113627, and image max is 0.893147
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.279805, and image max is 0.838843
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.111461, and image max is 0.93763
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.128181, and image max is 0.923525
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0052289, and image max is 0.915383
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.230207, and image max is 0.943275
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0430372, and image max is 0.885072
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.272402, and image max is 0.836312
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.299903, and image max is 0.800408
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00692002, and image max is 0.866068
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0275972, and image max is 0.913977
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0595485, and image max is 0.95448
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0130235, and image max is 0.715499
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0158501, and image max is 0.852624
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.0270213, and image max is 0.919392
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.161383, and image max is 0.85148
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.243241, and image max is 0.919809
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.160818, and image max is 0.887881
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0598533, and image max is 0.940904
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0656915, and image max is 0.88966
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0156362, and image max is 0.877762
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.170779, and image max is 0.946405
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is -0.00716955, and image max is 0.928292
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.000728676, and image max is 0.931563
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00335922, and image max is 0.925455
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.412752, and image max is 0.836718
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.299068, and image max is 0.845722
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.29808, and image max is 0.811223
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0746878, and image max is 0.885971
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0232585, and image max is 0.856834
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.274115, and image max is 0.867501
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.181816, and image max is 0.893723
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.218648, and image max is 0.88316
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.381042, and image max is 0.890088
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.124424, and image max is 0.91387
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.121748, and image max is 0.856251
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0230252, and image max is 0.856257
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0143522, and image max is 0.872112
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.025897, and image max is 0.85673
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.201248, and image max is 0.888891
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0502709, and image max is 0.871351
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.102528, and image max is 0.887761
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0719315, and image max is 0.810149
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.0606342, and image max is 0.922538
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.00403051, and image max is 0.88571
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0
# Tiff2LogSpect: image min is 0.193474, and image max is 0.930175
# Tiff2LogSpect: img.tag info says scale is 80.0, and shift is 0.0

# %%
# Analysis of the results of your classification
#------------------------------------------------

plt.plot(np.array(stats)[:,1])         # centroids of files in order read in (plotted in blue below)
plt.plot(np.array(stats_ordered)[:,1]) #centroids from min to max (plotted in orange below)

#Just for our own info, and paper writeups:
breaks=[baz[i][1] for i in range(0, 2000, 250)] # [0, 250, 500, 750, 1000, 1250, 1500, 1750]
breaks
# Out:
# [236.67602893192415,
#  1082.0064002897896,
#  1516.417826862348,
#  1878.7322219587122,
#  2231.337895423359,
#  2604.0829990052066,
#  3114.3237996031039,
#  3836.5578047115896]
